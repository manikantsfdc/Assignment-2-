# %%
#import libraries 
from bs4 import BeautifulSoup
import requests

response = requests.get('https://www.amazon.in/s?k=laptop&i=computers&rh=n%3A1375424031%2Cp_n_feature_thirteen_browse-bin%3A12598163031%7C16757432031&dc&qid=1604810434&rnid=12598141031&ref=sr_nr_p_n_feature_thirteen_browse-bin_16 ')
product_html = BeautifulSoup(response.content, 'html.parser')

print(response.status_code)

headers = product_html.find_all('div', attrs = {'class': 'a-section a-spacing-medium'})
# print(headers)
for box in headers:
    # print("Title: " + box.find('b').text)
    # print("Description: " + box.find_all('div')[-1].text)
    title = box.find('h2')
    print(title.text)
    price = box.find('span', attrs = {'class': 'a-price-whole'})
    print(price.text)
    star = box.find_all('i')[0]
    print(star.text)
# Out:
# 200

# %%
headers = product_html.find_all('div', attrs = {'class': 'a-section a-spacing-medium'})
# print(headers)
for box in headers:
    # print("Title: " + box.find('b').text)
    # print("Description: " + box.find_all('div')[-1].text)
    title = box.find('h2')
    print(title.text)
    price = box.find('span', attrs = {'class': 'a-price-whole'})
    print(price.text)
    star = box.find_all('i')[0]
    print(star.text)
# Out:
# (Renewed) Dell Inspiron 3567 Laptop Core i3-7th/6GB/1TB/15.6''/WIN 10 HOME
#
#
# 37,900
#
#
#
# HP Pavilion x360 Core i7 8th Gen 14-inch Touchscreen 2-in-1 FHD Thin and Light Laptop (16GB/512GB SSD/Windows 10/MS Office/2GB Graphics/Mineral Silver/1.59 kg), 14- dh0045TX and Bag Combo
#
#
# 82,789
# 3.8 out of 5 stars
#
#
# (Renewed) Dell Inspiron 5501 15.6 Inch FHD Laptop (10th Gen i7-1065G7/8 GB/512 SSD/2 GB Nvidia Graphics/Win 10 + MS Office H&S 2019/Silver) D560213WIN9S
#
#
# 73,092
#
#
#
# (Renewed) HP EliteBook 1030 G2 X 360 Notebook PC 13.3 inch Laptops (Intel® CoreTM i7-7500U Processor | 8GB RAM | 512GB SSD | Win10 PRO | Integrated Graphics ), Silver
#
#
# 49,990
# 2.2 out of 5 stars
#
#
# Lenovo Legion 5i 10th Gen Intel i7 15.6" FHD Gaming Laptop (8GB/1TB HDD + 256GB SSD/Win10/120Hz/NVIDIA GTX 1650 4GB GDDR6 Graphics/2.3Kg) 82AU00BAIN + Legion H300 Stereo Gaming Headset GXD0T69863
#
#
# 81,489
# 4.2 out of 5 stars
#
#
# ...
